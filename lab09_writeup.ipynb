# %% [markdown]
# # Lab 09
#
# # Your name here

# %% [markdown]
# This is a markdown cell; you can type words or equations in it.
#
# For basic formatting instructions: google `markdown jupyter notebook example`

# %%
# Put what was your "main code" in cells like this.
# Hold down `shift` and push `Enter` to run the code in a cell
# Break your main code into multiple cells, one cell per plot you make

# %% [markdown]
# The cell below will make the graphs interactive.

# %%
# %matplotlib notebook 
import matplotlib.pyplot as plt

import numpy as np

# %%
from dfts import

# %%
plt.plot([0,1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # In addition to saving and uploading this notebook, also:
#
# Go to `File` → `Download as` → `HTML`, save in the same folder as your code, and upload it to GitHub
